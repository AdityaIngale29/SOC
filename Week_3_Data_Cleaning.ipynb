# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaIngale29/SOC/blob/main/Week_3_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import io

# %%
from google.colab import files

uploaded=files.upload()
# Out:
#      <input type="file" id="files-ebc337ee-1059-4e4d-a014-ac997804dd6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ebc337ee-1059-4e4d-a014-ac997804dd6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving credit_train.csv to credit_train.csv

# %%
crt=pd.read_csv(io.BytesIO(uploaded['credit_train.csv']))
crt.head(10)
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
# 5  89d8cb0c-e5c2-4f54-b056-48a645c543dd  4ffe99d3-7f2a-44db-afc1-40943f1f9750
# 6  273581de-85d8-4332-81a5-19b04ce68666  90a75dde-34d5-419c-90dc-1e58b04b3e35
# 7  db0dc6e1-77ee-4826-acca-772f9039e1c7  018973c9-e316-4956-b363-67e134fb0931
# 8  8af915d9-9e91-44a0-b5a2-564a45c12089  af534dea-d27e-4fd6-9de8-efaa52a78ec0
# 9  0b1c4e3d-bd97-45ce-9622-22732fcdc9a0  235c4a43-dadf-483d-aa44-9d6d77ae4583
#
#    Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# ...

# %%
missing_value_counts=crt.isnull().sum()

print(missing_value_counts)

crt1=crt
# Out:
# Loan ID                           514
# Customer ID                       514
# Loan Status                       514
# Current Loan Amount               514
# Term                              514
# Credit Score                    19668
# Annual Income                   19668
# Years in current job             4736
# Home Ownership                    514
# Purpose                           514
# Monthly Debt                      514
# Years of Credit History           514
# Months since last delinquent    53655
# Number of Open Accounts           514
# Number of Credit Problems         514
# Current Credit Balance            514
# Maximum Open Credit               516
# Bankruptcies                      718
# Tax Liens                         524
# dtype: int64

# %%
total_cells=np.product(crt.shape)
total_missing=missing_value_counts.sum()

percentage_missing=(total_missing/total_cells)*100
print(percentage_missing)
# Out:
# 5.532248453475452

# %% [markdown]
# **Dropping the rows which contains NaN values **

# %%
crt=crt.dropna()
crt
# Out:
#                                     Loan ID  \
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 6      273581de-85d8-4332-81a5-19b04ce68666
# 8      8af915d9-9e91-44a0-b5a2-564a45c12089
# 10     32c2e48f-1ba8-45e0-a530-9a6622c18d9c
# 12     403d7235-0284-4bb6-919a-09402fecbf7b
# ...                                     ...
# 99990  686017b3-dc24-4f8a-af92-0bd077452d3d
# 99993  79b81158-5d55-4766-8ad6-ebcd683f7d59
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
#
#                                 Customer ID Loan Status  Current Loan Amount  \
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 6      90a75dde-34d5-419c-90dc-1e58b04b3e35  Fully Paid             217646.0
# 8      af534dea-d27e-4fd6-9de8-efaa52a78ec0  Fully Paid             548746.0
# 10     0de7bcdb-ebf4-4608-ba39-05f083f855b6  Fully Paid           99999999.0
# ...

# %%
len(crt.index)
# Out:
# 36423

# %%
crt1=crt1.fillna(-1)
crt1
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                    -1
# 100510                                    -1
# 100511                                    -1
# 100512                                    -1
# 100513                                    -1
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
crt1=crt1.loc[crt1['Loan ID']!=-1]
crt1=crt1.loc[crt1['Customer ID']!=-1]
crt1=crt1.loc[crt1['Maximum Open Credit']!=-1]
crt1=crt1.loc[crt1['Years in current job']!=-1]
crt1.loc[(crt1['Tax Liens']==-1), 'Tax Liens']=0
crt1.loc[(crt1.Bankruptcies==-1), 'Bankrupties']=0
crt1=crt1.loc[crt1['Annual Income']!=-1]
crt1=crt1.loc[crt1['Credit Score']!=-1]
crt1.loc[(crt1['Months since last delinquent']==-1), 'Months since last delinquent']=0
crt1
# Out:
#                                     Loan ID  \
# 0      14dd8831-6af5-400b-83ec-68e61888a048
# 2      4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3      77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 5      89d8cb0c-e5c2-4f54-b056-48a645c543dd
# 6      273581de-85d8-4332-81a5-19b04ce68666
# ...                                     ...
# 99994  8506a4e9-af7d-47d2-a1bf-7ea2c41858f0
# 99995  3f94c18c-ba8f-45d0-8610-88a684a410a9
# 99996  06eba04f-58fc-424a-b666-ed72aa008900
# 99997  e1cb4050-eff5-4bdb-a1b0-aabd3f7eaac7
# 99998  81ab928b-d1a5-4523-9a3c-271ebb01b4fb
#
#                                 Customer ID  Loan Status  Current Loan Amount  \
# 0      981165ec-3274-42f5-a3b4-d104041a9ca9   Fully Paid             445412.0
# 2      5efb2b2b-bf11-4dfd-a572-3761a2694725   Fully Paid           99999999.0
# 3      e777faab-98ae-45af-9a86-7ce5b33b1011   Fully Paid             347666.0
# 5      4ffe99d3-7f2a-44db-afc1-40943f1f9750  Charged Off             206602.0
# ...
