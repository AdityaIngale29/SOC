# %% [markdown]
# <a href="https://github.com/AdityaIngale29/SOC/blob/main/Week_Two_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get th dataset from
# https://www.kaggle.com/datasets/sootersaalu/amazon-top-50-bestselling-books-2009-2019

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io

# %% [markdown]
# ### Convert file into pandas dataframe

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c61a151-2e9f-4e2f-a981-4ac4ab83c2bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c61a151-2e9f-4e2f-a981-4ac4ab83c2bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bestsellers with categories.csv to bestsellers with categories (1).csv

# %%
df = pd.read_csv(io.BytesIO(uploaded['bestsellers with categories.csv']))
#print(df)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ### Print *first* 5 rows of dataframe

# %%
df.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
#  ### Print the number of rows.<br>Print the number of columns <br> Print the datatype of each variable.

# %%
print(f'Number of Rows: {len(df)}')
print(f'Number of columns: {len(df.columns)}')
df.info()
# Out:
# Number of Rows: 550
# Number of columns: 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# ### For each variable, print the number of unique values.<br>For each variable, display the number of missing entries.

# %%
print(len(np.unique(df.Name)))
print(len(np.unique(df.Author)))
print(len(np.unique(df['User Rating'])))
print(len(np.unique(df.Reviews)))
print(len(np.unique(df.Price)))
print(len(np.unique(df.Year)))
print(len(np.unique(df.Genre)))

print('')

print(len(df[df.Name.isnull()]))
print(len(df[df.Author.isnull()]))
print(len(df[df['User Rating'].isnull()]))
print(len(df[df.Reviews.isnull()]))
print(len(df[df.Price.isnull()]))
print(len(df[df.Year.isnull()]))
print(len(df[df.Genre.isnull()]))
# Out:
# 351
# 248
# 14
# 346
# 40
# 11
# 2
#
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ### Print statistical info of each numeric variable.(i.e. mean,meadian,..)

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# ### Find 20%,40%,60%,80% of variables

# %%
df.describe([0.2,0.4,0.6,0.8]) 
#You can also use np.percentile such as
#print(np.percentile(df.Price,20))
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 20%       4.500000   3477.000000    6.000000  2011.000000
# 40%       4.600000   6364.600000    9.000000  2013.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 60%       4.700000  10082.400000   13.000000  2015.000000
# 80%       4.800000  19637.400000   17.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# ### Print rows having 'To Kill a Mockingbird'

# %%
df[df.Name=='To Kill a Mockingbird']
# Out:
#                       Name      Author  User Rating  Reviews  Price  Year  \
# 505  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2013
# 506  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2014
# 507  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2015
# 508  To Kill a Mockingbird  Harper Lee          4.8    26234      0  2016
# 509  To Kill a Mockingbird  Harper Lee          4.8    26234      7  2019
#
#        Genre
# 505  Fiction
# 506  Fiction
# 507  Fiction
# 508  Fiction
# 509  Fiction

# %% [markdown]
# ### Remove Duplicates by name (Remove duplicates of the same name)

# %%
test=df.Name
test=list(set(test))
test
# Out:
# ['The Fault in Our Stars',
#  'Hillbilly Elegy: A Memoir of a Family and Culture in Crisis',
#  'Liberty and Tyranny: A Conservative Manifesto',
#  'Delivering Happiness: A Path to Profits, Passion, and Purpose',
#  'Autobiography of Mark Twain, Vol. 1',
#  'Winter of the World: Book Two of the Century Trilogy',
#  'If I Stay',
#  'A Dance with Dragons (A Song of Ice and Fire)',
#  'Killers of the Flower Moon: The Osage Murders and the Birth of the FBI',
#  "It's Not Supposed to Be This Way: Finding Unexpected Strength When Disappointments Leave You Shattered",
#  'The Pioneer Woman Cooks: Dinnertime - Comfort Classics, Freezer Food, 16-minute Meals, and Other Delicious Ways to Solve…',
#  'Dog Man: Brawl of the Wild: From the Creator of Captain Underpants (Dog Man #6)',
#  'Shred: The Revolutionary Diet: 6 Weeks 4 Inches 2 Sizes',
#  'Fifty Shades Freed: Book Three of the Fifty Shades Trilogy (Fifty Shades of Grey Series) (English Edition)',
#  'The Hunger Games',
# ...

# %% [markdown]
# ### Print name of all columns

# %%
print(df.columns)
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %% [markdown]
# ### Find info about movie 'Steve Jobs'(i.e.Print row of name 'Steve Jobs')

# %%
df[df.Name=='Steve Jobs']
# Out:
#            Name           Author  User Rating  Reviews  Price  Year  \
# 301  Steve Jobs  Walter Isaacson          4.6     7827     20  2011
# 302  Steve Jobs  Walter Isaacson          4.6     7827     20  2012
#
#            Genre
# 301  Non Fiction
# 302  Non Fiction

# %% [markdown]
# ### Plot Scatterplot of Price vs User Rating

# %%
df
plt.scatter(df['User Rating'],df.Price)
plt.show()

# %% [markdown]
# ### For each variable, plot the frequency of each unique value (histogram).

# %%
plt.hist(df.Name)
plt.show()

plt.hist(df.Author)
plt.show()

plt.hist(df['User Rating'])
plt.show()

plt.hist(df.Reviews)
plt.show()

plt.hist(df.Price)
plt.show()

plt.hist(df.Year)
plt.show()

plt.hist(df.Genre)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 133 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### Plot Box_Plot of each var

# %%
#data_1=df.Name
#data_2=df.Author
data_3=df['User Rating']
data_4=df.Reviews
data_5=df.Price
data_6=df.Year
#data_7=df.Genre

data=[data_3,data_4,data_5,data_6]

plt.boxplot(data_3)
plt.show()

plt.boxplot(data_4)
plt.show()

plt.boxplot(data_5)
plt.show()

plt.boxplot(data_6)
plt.show()
